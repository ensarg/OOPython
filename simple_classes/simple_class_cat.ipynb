# %% [markdown]
# <a href="https://colab.research.google.com/github/ensarg/OOPython/blob/main/simple_classes/simple_class_cat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install simpleaudio
# !pip install pydub
# !pip install playsound
# Out:
# Collecting simpleaudio
#   Downloading simpleaudio-1.0.4.tar.gz (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 11.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: simpleaudio
#   Building wheel for simpleaudio (setup.py) ... done
#   Created wheel for simpleaudio: filename=simpleaudio-1.0.4-cp311-cp311-linux_x86_64.whl size=2054421 sha256=c2667bd87d61fc684bd4249038884ab86b862e05b47de409ff95ad81de7eaa57
#   Stored in directory: /root/.cache/pip/wheels/44/74/11/9d2cf6ddf5d0dcc7750484a371b92fdb036f5496d1d4b42d08
# Successfully built simpleaudio
# Installing collected packages: simpleaudio
# Successfully installed simpleaudio-1.0.4
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: pydub
# Successfully installed pydub-0.25.1
# Collecting playsound
#   Downloading playsound-1.3.0.tar.gz (7.7 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: playsound
#   Building wheel for playsound (setup.py) ... done
#   Created wheel for playsound: filename=playsound-1.3.0-py3-none-any.whl size=7020 sha256=f0fd743218b82b2a8c9d79a78016cce47eb447f2a42bff658aac8a9fdd861479
#   Stored in directory: /root/.cache/pip/wheels/50/98/42/62753a9e1fb97579a0ce2f84f7db4c21c09d03bb2091e6cef4
# Successfully built playsound
# Installing collected packages: playsound
# Successfully installed playsound-1.3.0

# %%
#mount google drive
from google.colab import drive
drive.mount('/content/drive/',force_remount=True)
# !ls /content/drive/MyDrive/Colabs/OOPython/sounds
# %cd /content/drive/MyDrive/Colabs/OOPython/sounds
# Out:
# Mounted at /content/drive/
# cat2.wav  cat.wav
# /content/drive/MyDrive/Colabs/OOPython/sounds

# %%
import simpleaudio as sa
from pydub import AudioSegment
from pydub.playback import play
from playsound import playsound
class Cat:
    def __init__(self, name, age, color):
        self.name = name
        self.age = age
        self.color = color

    def get_name(self):
        return self.name

    def get_age(self):
        return self.age

    def get_color(self):
        return self.color

    def set_name(self, name):
        self.name = name

    def set_age(self, age):
        self.age = age

    def set_color(self, color):
        self.color = color

    def meow(self):
        print(f"{self.name} says: Meow!")
        try:
            #sound = AudioSegment.from_file("cat2.wav", format="wav")
            #play(sound)
            sound = Audio('cat2.wav', autoplay=True)
            display(sound)
        except Exception as e:
            print(f"Error playing sound: {e}")
# Out:
# WARNING:playsound:playsound is relying on another python subprocess. Please use `pip install pygobject` if you want playsound to run more efficiently.

# %%
from IPython.display import Audio
# Example usage
if __name__ == "__main__":
    my_cat = Cat("tekir", 3, "Gray")
    print(f"My cat's name is {my_cat.get_name()}")
    print(f"It is {my_cat.get_age()} years old.")
    print(f"Its color is {my_cat.get_color()}")

    my_cat.meow()
# Out:
# My cat's name is tekir
# It is 3 years old.
# Its color is Gray
# tekir says: Meow!
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
